# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['GEMINI_API_KEY']=os.getenv('GEMINI_API_KEY')
os.environ['LANGCHAIN_API']=os.getenv('LANGCHAIN_API')
os.environ['LANGCHAIN_PROJECT']=os.getenv('LANGCHAIN_PROJECT')
os.environ["LANGCHAIN_TRACING_V2"]="true"

# %%
import google.generativeai as genai  

GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

if not GEMINI_API_KEY:
    raise ValueError("Gemini Api Key not set")

genai.configure(api_key=GEMINI_API_KEY)

model = genai.GenerativeModel('gemini-2.5-flash-lite')

response = model.generate_content("Explain how photosynthesis works.")
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgument                           Traceback (most recent call last)
# Cell In[25], line 12
#       8 genai.configure(api_key=GEMINI_API_KEY)
#      10 model = genai.GenerativeModel('gemini-2.5-flash-lite')
# ---> 12 response = model.generate_content("Explain how photosynthesis works.")
#      13 print(response.text)
#
# File e:\MyAssist\venv\lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File e:\MyAssist\venv\lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File e:\MyAssist\venv\lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File e:\MyAssist\venv\lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File e:\MyAssist\venv\lib\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     152 # pylint: disable=broad-except
#     153 # This function explicitly must deal with broad exceptions.
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#     167     time.sleep(next_sleep)
#
# File e:\MyAssist\venv\lib\site-packages\google\api_core\retry\retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     208 if not predicate_fn(exc):
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#     216     on_error_fn(exc)
#
# File e:\MyAssist\venv\lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File e:\MyAssist\venv\lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File e:\MyAssist\venv\lib\site-packages\google\api_core\grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# InvalidArgument: 400 API key expired. Please renew the API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key expired. Please renew the API key."
# ]

# %%
from langchain_ollama import OllamaLLM

llm = OllamaLLM(model="gemma:2b") 

response = llm.invoke("explain photosynthesis in very detail")
print(response)
# Out:
# Sure, here is a detailed explanation of photosynthesis:
#
# **Photosynthesis** is the process by which plants and other organisms convert light energy into chemical energy in the form of sugar molecules. This process takes place in the chloroplasts of plant cells, which are small organelles found in plant leaves.
#
# **The steps of photosynthesis are:**
#
# **1. Light Absorption:**
# * Chlorophyll molecules, found in the chloroplasts, absorb light energy from the sun.
# * This energy is used to split water molecules into hydrogen and oxygen atoms.
# * The hydrogen atoms are used to combine with carbon dioxide molecules to form glucose (a type of sugar) molecules.
# * The oxygen atoms are released into the atmosphere.
#
# **2. Calvin Cycle:**
# * The glucose molecules produced in the first step are used in the Calvin cycle to convert them into smaller molecules.
# * These molecules, such as ribulose 1,5-bisphosphate (RuBP), are used to build larger molecules, such as starch.
# * The cycle also involves the release of energy from the glucose molecules, which is used to power the entire process.
#
# **3. Photorespiration:**
# * When photosynthesis is not sufficient to meet the energy demands of the plant, it can use oxygen to break down glucose molecules and release energy.
# * This process is called photorespiration.
#
# **The overall equation for photosynthesis is:**
#
# **6CO2 + 6H2O + light energy → C6H12O6 + 6O2**
#
# **Where:**
#
# * **6CO2** is the carbon dioxide absorbed from the atmosphere.
# * **6H2O** is the water that is split into hydrogen and oxygen atoms.
# * **C6H12O6** is the sugar molecule produced by the plant.
# * **6O2** is the oxygen that is released into the atmosphere.
#
# **Photosynthesis is a vital process for life on Earth. It provides the oxygen that we breathe and the food that we eat.**
#
# **Additional facts about photosynthesis:**
#
# * Photosynthesis is a highly efficient process, with an overall efficiency of around 1%.
# * The chloroplasts are the most efficient organelles in the plant body, with a high concentration of chlorophyll.
# * Photosynthesis is also a cyclic process, meaning that the products of the light-dependent reactions are used in the light-independent reactions.
# * Photosynthesis is a complex and dynamic process that is still not fully understood.
